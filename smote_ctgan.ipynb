# %%
# Importing the necessary libraries
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
from xgboost import XGBClassifier
from sklearn.ensemble import VotingClassifier
from imblearn.over_sampling import RandomOverSampler 
from imblearn.combine import SMOTETomek, SMOTEENN
import joblib

import os

# Defining the path for the csv file
path = os.path.join("dataset.csv")

# Storing the dataframe in a variable named dataset
dataset = pd.read_csv(path)

# Dropping the unnecessary columns
dataset = dataset.drop('seqn', axis='columns')
dataset = dataset.drop('Marital', axis='columns')
print(dataset.shape)
print(len(dataset[dataset['MetabolicSyndrome'] == 0]))
print(dataset.head())
# Out:
# (2401, 13)
# 1579
#    Age     Sex  Income   Race  WaistCirc   BMI  Albuminuria  UrAlbCr  \
# 0   22    Male  8200.0  White       81.0  23.3            0     3.88
# 1   44  Female  4500.0  White       80.1  23.2            0     8.55
# 2   21    Male   800.0  Asian       69.6  20.1            0     5.07
# 3   43  Female  2000.0  Black      120.4  33.3            0     5.22
# 4   51    Male     NaN  Asian       81.1  20.1            0     8.13
#
#    UricAcid  BloodGlucose  HDL  Triglycerides  MetabolicSyndrome
# 0       4.9            92   41             84                  0
# 1       4.5            82   28             56                  0
# 2       5.4           107   43             78                  0
# 3       5.0           104   73            141                  0
# 4       5.0            95   43            126                  0

# %%
sex_mapping = {'Male': 0, 'Female': 1}
race_mapping = {'White': 0, 'Asian': 1, 'Black': 2, 'MexAmerican': 3, 'Hispanic': 4, 'Other': 5}

dataset['Sex'] = dataset['Sex'].replace(sex_mapping)
dataset['Race'] = dataset['Race'].replace(race_mapping)

# This is the incorrect implementation
'''
dataset = dataset.fillna(2)
dataset = dataset.fillna(4)
dataset = dataset.fillna(5)
'''
# Fill NaN values in column with index 2
dataset.iloc[:, 2] = dataset.iloc[:, 2].fillna(dataset.iloc[:, 2].mean())

# Fill NaN values in column with index 4
dataset.iloc[:, 4] = dataset.iloc[:, 4].fillna(dataset.iloc[:, 4].mean())

# Fill NaN values in column with index 5
dataset.iloc[:, 5] = dataset.iloc[:, 5].fillna(dataset.iloc[:, 5].mean())
print(dataset.head())
# Out:
#    Age  Sex      Income  Race  WaistCirc   BMI  Albuminuria  UrAlbCr  \
# 0   22    0  8200.00000     0       81.0  23.3            0     3.88
# 1   44    1  4500.00000     0       80.1  23.2            0     8.55
# 2   21    0   800.00000     1       69.6  20.1            0     5.07
# 3   43    1  2000.00000     2      120.4  33.3            0     5.22
# 4   51    0  4005.25394     1       81.1  20.1            0     8.13
#
#    UricAcid  BloodGlucose  HDL  Triglycerides  MetabolicSyndrome
# 0       4.9            92   41             84                  0
# 1       4.5            82   28             56                  0
# 2       5.4           107   43             78                  0
# 3       5.0           104   73            141                  0
# 4       5.0            95   43            126                  0
# /var/folders/8t/p012qq114lj2w2v6rb72_p1c0000gn/T/ipykernel_50120/4086439163.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dataset['Sex'] = dataset['Sex'].replace(sex_mapping)
# /var/folders/8t/p012qq114lj2w2v6rb72_p1c0000gn/T/ipykernel_50120/4086439163.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dataset['Race'] = dataset['Race'].replace(race_mapping)

# %%
outcome_0 = dataset[dataset['MetabolicSyndrome'] == 0]
outcome_1 = dataset[dataset['MetabolicSyndrome'] == 1]


test_size_each_class = 400
test_0 = outcome_0.sample(n=test_size_each_class, random_state=42)
test_1 = outcome_1.sample(n=test_size_each_class, random_state=42)
#print(test_1)
test_data = pd.concat([test_0, test_1])

# Remove the test set rows from the original dataset to create the training set
train_data = dataset.drop(test_data.index)


x_train = train_data.drop('MetabolicSyndrome', axis=1).values
y_train = train_data['MetabolicSyndrome'].values
x_test = test_data.drop('MetabolicSyndrome', axis=1).values
y_test = test_data['MetabolicSyndrome'].values
from imblearn.over_sampling import SMOTE
from ctgan import CTGAN

# %%
def generate_synthetic_samples(train_data, method='combined', weights=(0.5, 0.5)):
    """
    Generate synthetic samples using a weighted combination of smote and CTGAN.
    """
    train_data = train_data.dropna(subset=['MetabolicSyndrome'])

    X = train_data.drop('MetabolicSyndrome', axis=1)
    y = train_data['MetabolicSyndrome']

    # Identify discrete (categorical) columns in your dataset
    discrete_columns = X.select_dtypes(include=['object', 'category']).columns.tolist()
    
    # Generate synthetic samples using smote
    smote = SMOTE(random_state=42)
    X_smote, y_smote = smote.fit_resample(X, y)
    smote_samples = pd.DataFrame(X_smote[len(X):], columns=X.columns)

    # Generate synthetic samples using CTGAN
    ctgan = CTGAN(epochs=300)
    ctgan.fit(X, discrete_columns)
    ctgan_samples = ctgan.sample(len(smote_samples))
    ctgan_samples.columns = X.columns  # Ensure columns match original data

    if method == 'smote':
        final_synthetic = smote_samples
    elif method == 'ctgan':
        final_synthetic = ctgan_samples
    else:  # Combined method
        n_smote = int(weights[0] * len(smote_samples))
        n_ctgan = len(smote_samples) - n_smote

        final_synthetic = pd.concat([
            smote_samples.sample(n=n_smote, random_state=42, replace=True),
            ctgan_samples.sample(n=n_ctgan, random_state=42, replace=True)
        ])

    final_synthetic['MetabolicSyndrome'] = 1  # Assuming synthetic samples are for the minority class
    balanced_data = pd.concat([train_data, final_synthetic])

    return balanced_data

# %%
import xgboost as xgb
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Assuming train_data and test_data are pandas DataFrames
# Generate synthetic data using the custom function
# 0.14289794020845348, 0.8571020597915465
balanced_train_data = generate_synthetic_samples(train_data, method='combined', weights=(0.4, 0.6))

# Split features and labels
X_train = balanced_train_data.drop('MetabolicSyndrome', axis=1)
y_train = balanced_train_data['MetabolicSyndrome']

X_test = test_data.drop('MetabolicSyndrome', axis=1)
y_test = test_data['MetabolicSyndrome']

# Create an XGBoost classifier
xgb_model = xgb.XGBClassifier(n_estimators=100, max_depth=3, learning_rate=0.1, random_state=42)

# Train the model
xgb_model.fit(X_train, y_train)

# Predict on test data
y_pred = xgb_model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

# Display evaluation metrics
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Accuracy: 0.8500
# Precision: 0.8784
# Recall: 0.8125
# F1 Score: 0.8442

# %%
import xgboost as xgb
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Assuming train_data and test_data are pandas DataFrames
# Generate synthetic data using the custom function
# 0.14289794020845348, 0.8571020597915465
balanced_train_data = generate_synthetic_samples(train_data, method='combined', weights=(0.39916032571689625, 0.6008396742831037))

# Split features and labels
X_train = balanced_train_data.drop('MetabolicSyndrome', axis=1)
y_train = balanced_train_data['MetabolicSyndrome']

X_test = test_data.drop('MetabolicSyndrome', axis=1)
y_test = test_data['MetabolicSyndrome']

# Create an XGBoost classifier
xgb_model = xgb.XGBClassifier(n_estimators=100, max_depth=3, learning_rate=0.1, random_state=42)

# Train the model
xgb_model.fit(X_train, y_train)

# Predict on test data
y_pred = xgb_model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

# Display evaluation metrics
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Accuracy: 0.8588
# Precision: 0.8689
# Recall: 0.8450
# F1 Score: 0.8568

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from xgboost import XGBClassifier
from imblearn.over_sampling import SMOTE 
from ctgan import CTGAN
import os

# Load the dataset
path = os.path.join("dataset.csv")
dataset = pd.read_csv(path)

# Drop unnecessary columns
dataset = dataset.drop(['seqn', 'Marital'], axis='columns')

# Map categorical variables to numerical values
sex_mapping = {'Male': 0, 'Female': 1}
race_mapping = {'White': 0, 'Asian': 1, 'Black': 2, 'MexAmerican': 3, 'Hispanic': 4, 'Other': 5}
dataset['Sex'] = dataset['Sex'].replace(sex_mapping)
dataset['Race'] = dataset['Race'].replace(race_mapping)

# Fill NaN values with the mean of the respective columns
dataset.iloc[:, 2] = dataset.iloc[:, 2].fillna(dataset.iloc[:, 2].mean())
dataset.iloc[:, 4] = dataset.iloc[:, 4].fillna(dataset.iloc[:, 4].mean())
dataset.iloc[:, 5] = dataset.iloc[:, 5].fillna(dataset.iloc[:, 5].mean())

# Clean the dataset before splitting
dataset = dataset.dropna(subset=['MetabolicSyndrome'])

# Split the data into training and test sets
outcome_0 = dataset[dataset['MetabolicSyndrome'] == 0]
outcome_1 = dataset[dataset['MetabolicSyndrome'] == 1]
test_size_each_class = 400
test_0 = outcome_0.sample(n=test_size_each_class, random_state=42)
test_1 = outcome_1.sample(n=test_size_each_class, random_state=42)
test_data = pd.concat([test_0, test_1])
train_data = dataset.drop(test_data.index)

# Define a function to generate synthetic samples using ADASYN and CTGAN
def generate_synthetic_samples(train_data, method='combined', weights=(0.5, 0.5)):
    train_data = train_data.dropna(subset=['MetabolicSyndrome'])

    X = train_data.drop('MetabolicSyndrome', axis=1)
    y = train_data['MetabolicSyndrome']

    # Identify discrete (categorical) columns in your dataset
    discrete_columns = X.select_dtypes(include=['object', 'category']).columns.tolist()
    
    # Generate synthetic samples using ADASYN
    smote = SMOTE(random_state=42)
    X_smote , y_smote= smote.fit_resample(X, y)
    smote_samples = pd.DataFrame(X_smote[len(X):], columns=X.columns)

    # Generate synthetic samples using CTGAN
    ctgan = CTGAN(epochs=300)
    ctgan.fit(X, discrete_columns)
    ctgan_samples = ctgan.sample(len(smote_samples))
    ctgan_samples.columns = X.columns  # Ensure columns match original data

    if method == 'smote':
        final_synthetic = smote_samples
    elif method == 'ctgan':
        final_synthetic = ctgan_samples
    else:  # Combined method
        n_smote = int(weights[0] * len(smote_samples))
        n_ctgan = len(smote_samples) - n_smote

        final_synthetic = pd.concat([
            smote_samples.sample(n=n_smote, random_state=42, replace=True),
            ctgan_samples.sample(n=n_ctgan, random_state=42, replace=True)
        ])

    final_synthetic['MetabolicSyndrome'] = 1  # Assuming synthetic samples are for the minority class
    balanced_data = pd.concat([train_data, final_synthetic])

    return balanced_data

# Function to train and evaluate model
def evaluate_model(train_data, test_data):
    X_train = train_data.drop('MetabolicSyndrome', axis=1).values
    y_train = train_data['MetabolicSyndrome'].values
    X_test = test_data.drop('MetabolicSyndrome', axis=1).values
    y_test = test_data['MetabolicSyndrome'].values
    
    model = XGBClassifier(random_state=42, n_estimators=100, learning_rate=0.3, max_depth=3)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    
    return {
        'accuracy': accuracy_score(y_test, y_pred),
        'precision': precision_score(y_test, y_pred),
        'recall': recall_score(y_test, y_pred),
        'f1': f1_score(y_test, y_pred)
    }

# Define a function to evaluate multiple weight combinations and store results in a CSV file
def evaluate_and_store_results(train_data, test_data):
    results_list = []

    # Iterate over lambda values from 0 to 1 with a step of 0.05
    for lambda_value in np.arange(0, 1.05, 0.05):
        weights = (lambda_value, 1 - lambda_value)
        balanced_data_combined = generate_synthetic_samples(train_data, method='combined', weights=weights)

        # Ensure sample size does not exceed population
        if len(balanced_data_combined) > len(train_data):
            balanced_data_combined = balanced_data_combined.sample(n=len(train_data), random_state=42, replace=True)

        results = evaluate_model(balanced_data_combined, test_data)

        # Store the results along with the lambda value and weights
        results_list.append({
            'lambda': lambda_value,
            'weights': weights,
            'accuracy': results['accuracy'],
            'precision': results['precision'],
            'recall': results['recall'],
            'f1': results['f1']
        })
        print(f"Lambda: {lambda_value:.2f}, Weights: {weights}, Results: {results}")

    # Convert the results list to a DataFrame and save it as a CSV file
    results_df = pd.DataFrame(results_list)
    results_df.to_csv('smote_ctgan_evaluation_results_300.csv', index=False)

# Evaluate and store the results in a CSV file
evaluate_and_store_results(train_data, test_data)

print("Evaluation results have been stored in evaluation_results.csv")
# Out:
# Lambda: 0.00, Weights: (0.0, 1.0), Results: {'accuracy': 0.8225, 'precision': 0.8664772727272727, 'recall': 0.7625, 'f1': 0.8111702127659575}
# Lambda: 0.05, Weights: (0.05, 0.95), Results: {'accuracy': 0.86125, 'precision': 0.9140401146131805, 'recall': 0.7975, 'f1': 0.8518024032042723}
# Lambda: 0.10, Weights: (0.1, 0.9), Results: {'accuracy': 0.86125, 'precision': 0.8980716253443526, 'recall': 0.815, 'f1': 0.8545216251638269}
# Lambda: 0.15, Weights: (0.15000000000000002, 0.85), Results: {'accuracy': 0.84625, 'precision': 0.8794520547945206, 'recall': 0.8025, 'f1': 0.8392156862745098}
# Lambda: 0.20, Weights: (0.2, 0.8), Results: {'accuracy': 0.8425, 'precision': 0.88268156424581, 'recall': 0.79, 'f1': 0.8337730870712402}
# Lambda: 0.25, Weights: (0.25, 0.75), Results: {'accuracy': 0.8625, 'precision': 0.8918918918918919, 'recall': 0.825, 'f1': 0.8571428571428571}
# Lambda: 0.30, Weights: (0.30000000000000004, 0.7), Results: {'accuracy': 0.83375, 'precision': 0.8739495798319328, 'recall': 0.78, 'f1': 0.8243064729194188}
# Lambda: 0.35, Weights: (0.35000000000000003, 0.6499999999999999), Results: {'accuracy': 0.84125, 'precision': 0.8760330578512396, 'recall': 0.795, 'f1': 0.8335517693315858}
# Lambda: 0.40, Weights: (0.4, 0.6), Results: {'accuracy': 0.85, 'precision': 0.8723404255319149, 'recall': 0.82, 'f1': 0.8453608247422681}
# Lambda: 0.45, Weights: (0.45, 0.55), Results: {'accuracy': 0.845, 'precision': 0.8556701030927835, 'recall': 0.83, 'f1': 0.8426395939086294}
# Lambda: 0.50, Weights: (0.5, 0.5), Results: {'accuracy': 0.86875, 'precision': 0.8912466843501327, 'recall': 0.84, 'f1': 0.8648648648648649}
# Lambda: 0.55, Weights: (0.55, 0.44999999999999996), Results: {'accuracy': 0.86, 'precision': 0.8789473684210526, 'recall': 0.835, 'f1': 0.8564102564102565}
# Lambda: 0.60, Weights: (0.6000000000000001, 0.3999999999999999), Results: {'accuracy': 0.86, 'precision': 0.8829787234042553, 'recall': 0.83, 'f1': 0.8556701030927835}
# Lambda: 0.65, Weights: (0.65, 0.35), Results: {'accuracy': 0.855, 'precision': 0.865979381443299, 'recall': 0.84, 'f1': 0.8527918781725888}
# Lambda: 0.70, Weights: (0.7000000000000001, 0.29999999999999993), Results: {'accuracy': 0.85625, 'precision': 0.8840970350404312, 'recall': 0.82, 'f1': 0.8508430609597925}
# Lambda: 0.75, Weights: (0.75, 0.25), Results: {'accuracy': 0.84875, 'precision': 0.8531645569620253, 'recall': 0.8425, 'f1': 0.8477987421383648}
# Lambda: 0.80, Weights: (0.8, 0.19999999999999996), Results: {'accuracy': 0.835, 'precision': 0.8366834170854272, 'recall': 0.8325, 'f1': 0.8345864661654135}
# Lambda: 0.85, Weights: (0.8500000000000001, 0.1499999999999999), Results: {'accuracy': 0.84625, 'precision': 0.8654353562005277, 'recall': 0.82, 'f1': 0.8421052631578947}
# Lambda: 0.90, Weights: (0.9, 0.09999999999999998), Results: {'accuracy': 0.865, 'precision': 0.8705583756345178, 'recall': 0.8575, 'f1': 0.8639798488664988}
# Lambda: 0.95, Weights: (0.9500000000000001, 0.04999999999999993), Results: {'accuracy': 0.8575, 'precision': 0.8704663212435233, 'recall': 0.84, 'f1': 0.8549618320610687}
# Lambda: 1.00, Weights: (1.0, 0.0), Results: {'accuracy': 0.8575, 'precision': 0.8647959183673469, 'recall': 0.8475, 'f1': 0.8560606060606061}
# Evaluation results have been stored in evaluation_results.csv

# %%
import joblib
import numpy as np
import xgboost as xgb
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from scipy.stats import beta

# Function to evaluate the model
def evaluate_model(train_data, test_data, weights):
    # Generate synthetic data with the current weight combination
    balanced_train_data = generate_synthetic_samples(train_data, method='combined', weights=weights)

    # Split features and labels
    X_train = balanced_train_data.drop('MetabolicSyndrome', axis=1)
    y_train = balanced_train_data['MetabolicSyndrome']
    X_test = test_data.drop('MetabolicSyndrome', axis=1)
    y_test = test_data['MetabolicSyndrome']

    # Create and train the XGBoost model
    xgb_model = xgb.XGBClassifier(n_estimators=100, max_depth=3, learning_rate=0.1, random_state=42)
    xgb_model.fit(X_train, y_train)

    # Predict and evaluate
    y_pred = xgb_model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)

    return accuracy, precision, recall, f1, xgb_model

# Function to find the best weight combination
def find_best_weight_combination_beta(train_data, test_data, num_samples=20, alpha=2, beta_param=2):
    best_accuracy = 0
    best_weights = (0, 0)
    best_results = {}
    best_model = None

    # Sample weights from a Beta distribution
    for _ in range(num_samples):
        # Randomly sample a weight for ADASYN and CTGAN from a Beta distribution
        weight_smote = beta.rvs(alpha, beta_param)
        weight_ctgan = 1 - weight_smote

        weights = (weight_smote, weight_ctgan)

        # Evaluate the model with the current weights
        accuracy, precision, recall, f1, xgb_model = evaluate_model(train_data, test_data, weights)

        # If this combination performs better, update best weights and results
        if accuracy > best_accuracy:
            best_accuracy = accuracy
            best_weights = weights
            best_results = {
                'accuracy': accuracy,
                'precision': precision,
                'recall': recall,
                'f1': f1
            }
            best_model = xgb_model

    return best_weights, best_results, best_model

# Run the weight optimization
optimal_weights, optimal_results, best_model = find_best_weight_combination_beta(train_data, test_data)

# Save the best model

# Display the best weights and corresponding evaluation metrics
print(f"\nOptimal Weight Combination (ADASYN, CTGAN): {optimal_weights}")
print(f"\nOptimal Combined Method Results:")
print(optimal_results)

# 0.39916032571689625, 0.6008396742831037
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 64
#      61     return best_weights, best_results, best_model
#      63 # Run the weight optimization
# ---> 64 optimal_weights, optimal_results, best_model = find_best_weight_combination_beta(train_data, test_data)
#      66 # Save the best model
#      67
#      68 # Display the best weights and corresponding evaluation metrics
#      69 print(f"\nOptimal Weight Combination (ADASYN, CTGAN): {optimal_weights}")
#
# Cell In[7], line 47, in find_best_weight_combination_beta(train_data, test_data, num_samples, alpha, beta_param)
#      44 weights = (weight_adasyn, weight_ctgan)
#      46 # Evaluate the model with the current weights
# ---> 47 accuracy, precision, recall, f1, xgb_model = evaluate_model(train_data, test_data, weights)
#      49 # If this combination performs better, update best weights and results
#      50 if accuracy > best_accuracy:
#
# Cell In[7], line 10, in evaluate_model(train_data, test_data, weights)
#       8 def evaluate_model(train_data, test_data, weights):
#       9     # Generate synthetic data with the current weight combination
# ---> 10     balanced_train_data = generate_synthetic_samples(train_data, method='combined', weights=weights)
#      12     # Split features and labels
#      13     X_train = balanced_train_data.drop('MetabolicSyndrome', axis=1)
#
# Cell In[4], line 20, in generate_synthetic_samples(train_data, method, weights)
#      18 # Generate synthetic samples using CTGAN
#      19 ctgan = CTGAN(epochs=300)
# ---> 20 ctgan.fit(X, discrete_columns)
#      21 ctgan_samples = ctgan.sample(len(smote_samples))
#      22 ctgan_samples.columns = X.columns  # Ensure columns match original data
#
# File ~/anaconda3/lib/python3.11/site-packages/ctgan/synthesizers/base.py:50, in random_state.<locals>.wrapper(self, *args, **kwargs)
#      48 def wrapper(self, *args, **kwargs):
#      49     if self.random_states is None:
# ---> 50         return function(self, *args, **kwargs)
#      52     else:
#      53         with set_random_states(self.random_states, self.set_random_state):
#
# File ~/anaconda3/lib/python3.11/site-packages/ctgan/synthesizers/ctgan.py:401, in CTGAN.fit(self, train_data, discrete_columns, epochs)
#     398 y_fake = discriminator(fake_cat)
#     399 y_real = discriminator(real_cat)
# --> 401 pen = discriminator.calc_gradient_penalty(
#     402     real_cat, fake_cat, self._device, self.pac
#     403 )
#     404 loss_d = -(torch.mean(y_real) - torch.mean(y_fake))
#     406 optimizerD.zero_grad(set_to_none=False)
#
# File ~/anaconda3/lib/python3.11/site-packages/ctgan/synthesizers/ctgan.py:41, in Discriminator.calc_gradient_penalty(self, real_data, fake_data, device, pac, lambda_)
#      37 alpha = alpha.view(-1, real_data.size(1))
#      39 interpolates = alpha * real_data + ((1 - alpha) * fake_data)
# ---> 41 disc_interpolates = self(interpolates)
#      43 gradients = torch.autograd.grad(
#      44     outputs=disc_interpolates,
#      45     inputs=interpolates,
#    (...)
#      49     only_inputs=True,
#      50 )[0]
#      52 gradients_view = gradients.view(-1, pac * real_data.size(1)).norm(2, dim=1) - 1
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/anaconda3/lib/python3.11/site-packages/ctgan/synthesizers/ctgan.py:60, in Discriminator.forward(self, input_)
#      58 """Apply the Discriminator to the `input_`."""
#      59 assert input_.size()[0] % self.pac == 0
# ---> 60 return self.seq(input_.view(-1, self.pacdim))
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/container.py:219, in Sequential.forward(self, input)
#     217 def forward(self, input):
#     218     for module in self:
# --> 219         input = module(input)
#     220     return input
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/dropout.py:59, in Dropout.forward(self, input)
#      58 def forward(self, input: Tensor) -> Tensor:
# ---> 59     return F.dropout(input, self.p, self.training, self.inplace)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/functional.py:1295, in dropout(input, p, training, inplace)
#    1293 if p < 0.0 or p > 1.0:
#    1294     raise ValueError(f"dropout probability has to be between 0 and 1, but got {p}")
# -> 1295 return _VF.dropout_(input, p, training) if inplace else _VF.dropout(input, p, training)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/_VF.py:27, in VFModule.__getattr__(self, attr)
#      26 def __getattr__(self, attr):
# ---> 27     return getattr(self.vf, attr)
#
# KeyboardInterrupt:
